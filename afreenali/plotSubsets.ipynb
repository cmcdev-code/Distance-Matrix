# %%
import folium
from folium import Map, Marker, Icon, Element
import pandas as pd 

### Time 0

# Load the data from excel sheet
time0 = pd.read_excel("Subsets_Afreen.xlsx", engine="openpyxl", sheet_name="Time 0")

# convert to csv file 
time0.to_csv("Time 0.csv",index=False)

# read csv file 
time0_df = pd.read_csv("Time 0.csv", header=0)

#clean data 
time0_df.columns = time0_df.columns.str.strip()

# list of tuples that zips together each row household's data with the following columns
coords = list(zip(time0_df['Latitude'], time0_df['Longitude'], 
                  time0_df['Preferred ID'], time0_df['Household size'], 
                  time0_df['Capacity'], time0_df['Delivery Amount'], 
                  time0_df['Inventory'], time0_df['Code for water storage tank']))
# plot on map
time0_m = folium.Map(tiles='OpenStreetMap')

# assign color based on water tank code
def get_color(water_tank_code):
    color_mapping = {
        1200: 'blue',
        275: 'red',
        1000: 'beige',
        1475: 'purple',
        1275: 'orange',
        2200: 'green',
        2475: 'lightgray',
        2000: 'lightgreen',
        3200: 'cadetblue'  
    }
    return color_mapping.get(water_tank_code, 'black')  # black for office and water depots  

# markers colored based on water tank code with popup and hover 
for lat, lon, id, household_size, capacity, delivery_amount, inventory, water_tank_code in coords:
    color = get_color(water_tank_code)
    folium.Marker(
        [lat, lon],
        icon=folium.Icon(color=color),
        tooltip=f"Preferred ID: {id}",  # tooltip for hover
        popup=( 
            f"<b>Household Size:</b> {household_size}<br>"
            f"<b>Capacity:</b> {capacity}<br>"
            f"<b>Delivery Amount:</b> {delivery_amount}<br>"
            f"<b>Inventory:</b> {inventory}"  
        )  # popup for click
    ).add_to(time0_m)

# coordinates to recenter map around zoomed in region 
sw = [35.3, -108]  
ne = [35.65, -109]  
time0_m.fit_bounds([sw, ne])

# add title to map
title_html = """
<h3 align="center" style="font-size:24px; margin-top:10px;">
    Route - Time 0
</h3>
"""
time0_m.get_root().html.add_child(Element(title_html))

# save to HTML file
time0_m.save("Time0.html")
time0_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ca2842448639f5bb0506947c6bfe0b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;h3 align=&quot;center&quot; style=&quot;font-size:24px; margin-top:10px;&quot;&gt;
#     Route - Time 0
# &lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ca2842448639f5bb0506947c6bfe0b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ca2842448639f5bb0506947c6bfe0b5 = L.map(
#                 &quot;map_4ca2842448639f5bb0506947c6bfe0b5&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_918c9c45eb473bad99650526ac0aaeff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_918c9c45eb473bad99650526ac0aaeff.addTo(map_4ca2842448639f5bb0506947c6bfe0b5);
#
#
#             var marker_cc97492b4e9fd49dec5b2babcce202cd = L.marker(
#                 [35.407167, -108.234917],
#                 {
# }
#             ).addTo(map_4ca2842448639f5bb0506947c6bfe0b5);
#
#
#             var icon_d0ca1f3973ca06557e5771fc23678c14 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6c0797455ae439ac7c27d1e6acf0d556 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9038d1c9b2241956f6e56e1c68f041dd = $(`&lt;div id=&quot;html_9038d1c9b2241956f6e56e1c68f041dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; nan&lt;/div&gt;`)[0];
#                 popup_6c0797455ae439ac7c27d1e6acf0d556.setContent(html_9038d1c9b2241956f6e56e1c68f041dd);
#
#
#
#         marker_cc97492b4e9fd49dec5b2babcce202cd.bindPopup(popup_6c0797455ae439ac7c27d1e6acf0d556)
#         ;
#
#
#
#
#             marker_cc97492b4e9fd49dec5b2babcce202cd.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Depot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_cc97492b4e9fd49dec5b2babcce202cd.setIcon(icon_d0ca1f3973ca06557e5771fc23678c14);
#
#
#             var marker_df392b8b8325f2a45191fe3efe694513 = L.marker(
#                 [35.32923797, -108.8098128],
#                 {
# }
#             ).addTo(map_4ca2842448639f5bb0506947c6bfe0b5);
#
#
#             var icon_733ccd9f773245d378a573159381219e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8ad903af11f05b5c8c599544530be5a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1fea4a5240552f823d4e2db503c8a6f8 = $(`&lt;div id=&quot;html_1fea4a5240552f823d4e2db503c8a6f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; 5.0&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; 1200.0&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; 0.0&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; 0.0&lt;/div&gt;`)[0];
#                 popup_8ad903af11f05b5c8c599544530be5a9.setContent(html_1fea4a5240552f823d4e2db503c8a6f8);
#
#
#
#         marker_df392b8b8325f2a45191fe3efe694513.bindPopup(popup_8ad903af11f05b5c8c599544530be5a9)
#         ;
#
#
#
#
#             marker_df392b8b8325f2a45191fe3efe694513.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Customer 1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_df392b8b8325f2a45191fe3efe694513.setIcon(icon_733ccd9f773245d378a573159381219e);
#
#
#             var marker_b1ade050394b82969651e5d379dfa3b4 = L.marker(
#                 [35.6101355, -108.5282439],
#                 {
# }
#             ).addTo(map_4ca2842448639f5bb0506947c6bfe0b5);
#
#
#             var icon_9f0c0f487175d39f6b2e2969df6cd94b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;beige&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_66067c403e5ac9cd0adf61bad8d488bc = L.popup(

# %%
### Time 1

# Load the data from excel sheet
time1 = pd.read_excel("Subsets_Afreen.xlsx", engine="openpyxl", sheet_name="Time 1")

# convert to csv file 
time1.to_csv("Time 1.csv",index=False)

# read csv file 
time1_df = pd.read_csv("Time 1.csv", header=0)

# clean data
time1_df.columns = time0_df.columns.str.strip()

# list of tuples that zips together each row household's data with the following columns
coords = list(zip(time1_df['Latitude'], time1_df['Longitude'], 
                  time1_df['Preferred ID'], time1_df['Household size'], 
                  time1_df['Capacity'], time1_df['Delivery Amount'], 
                  time1_df['Inventory'], time1_df['Code for water storage tank']))

# plot on map
time1_m = folium.Map(tiles='OpenStreetMap')

# assign color based on water tank code
def get_color(water_tank_code):
    color_mapping = {
        1200: 'blue',
        275: 'red',
        1000: 'beige',
        1475: 'purple',
        1275: 'orange',
        2200: 'green',
        2475: 'lightgray',
        2000: 'lightgreen',
        3200: 'cadetblue'  
    }
    return color_mapping.get(water_tank_code, 'black')  # black for office and water depots 

# markers colored based on water tank code with popup and hover 
for lat, lon, id, household_size, capacity, delivery_amount, inventory, water_tank_code in coords:
    color = get_color(water_tank_code)
    folium.Marker(
        [lat, lon],
        icon=folium.Icon(color=color),
        tooltip=f"Preferred ID: {id}",  # tooltip for hover
        popup=( 
            f"<b>Household Size:</b> {household_size}<br>"
            f"<b>Capacity:</b> {capacity}<br>"
            f"<b>Delivery Amount:</b> {delivery_amount}<br>"
            f"<b>Inventory:</b> {inventory}"  
        )  # popup for click
    ).add_to(time1_m)

# southwestern US 
sw = [35.3, -108]  
ne = [35.65, -109]  
time1_m.fit_bounds([sw, ne])

# coordinates for line paths between households 
coordinates = [
    [35.407167, -108.234917],
    [35.32923797, -108.8098128],
    [35.46312211, -108.9559325],
    [35.6101355, -108.5282439],
    [35.36235925, -107.968078],
    [35.36601699, -108.0755568],
    [35.407167, -108.234917]
]

# Add Polyline to the Map
folium.PolyLine(
    locations=coordinates,  
    color="black",         
    weight=3,               
    opacity=0.7            
).add_to(time1_m)

# loop to add segment labels 
for i in range(len(coordinates) - 1):
    lat1, lon1 = coordinates[i]
    lat2, lon2 = coordinates[i + 1]
    
    # Calculate midpoint
    mid_lat = (lat1 + lat2) / 2
    mid_lon = (lon1 + lon2) / 2

    # Add marker with segment number
    folium.Marker(
        location=[mid_lat, mid_lon],
        icon=folium.DivIcon(html=f'''
                <div style="
                    font-size: 12pt; 
                    font-weight: bold; 
                    color: black; 
                    background-color: white;
                    padding: 2px; 
                    border-radius: 5px;
                    text-align: center;
                ">
                    {i + 1}
                </div>
            '''),
            tooltip=f"Segment {i + 1}"
    ).add_to(time1_m)

# add title to map
title_html = """
<h3 align="center" style="font-size:24px; margin-top:10px;">
    Route - Time 1
</h3>
"""
time1_m.get_root().html.add_child(Element(title_html))

# save to HTML file
time1_m.save("Time1.html")
time1_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ceacb0480bdd5d228ae800f58aa661b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;h3 align=&quot;center&quot; style=&quot;font-size:24px; margin-top:10px;&quot;&gt;
#     Route - Time 1
# &lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ceacb0480bdd5d228ae800f58aa661b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ceacb0480bdd5d228ae800f58aa661b = L.map(
#                 &quot;map_3ceacb0480bdd5d228ae800f58aa661b&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13f6d2465de19bf1a091cbb9ba5cfaba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_13f6d2465de19bf1a091cbb9ba5cfaba.addTo(map_3ceacb0480bdd5d228ae800f58aa661b);
#
#
#             var marker_8c62e8a0bde130096eef9cc311091372 = L.marker(
#                 [35.407167, -108.234917],
#                 {
# }
#             ).addTo(map_3ceacb0480bdd5d228ae800f58aa661b);
#
#
#             var icon_78410bb572bb3ad5787017cdab061fd8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_01231eb30d8c541842203dde677058e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed633f0343caa12ee4a0391502214f49 = $(`&lt;div id=&quot;html_ed633f0343caa12ee4a0391502214f49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; nan&lt;/div&gt;`)[0];
#                 popup_01231eb30d8c541842203dde677058e0.setContent(html_ed633f0343caa12ee4a0391502214f49);
#
#
#
#         marker_8c62e8a0bde130096eef9cc311091372.bindPopup(popup_01231eb30d8c541842203dde677058e0)
#         ;
#
#
#
#
#             marker_8c62e8a0bde130096eef9cc311091372.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Depot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_8c62e8a0bde130096eef9cc311091372.setIcon(icon_78410bb572bb3ad5787017cdab061fd8);
#
#
#             var marker_0fc89efa827f96f2ea9908153e02e5ef = L.marker(
#                 [35.32923797, -108.8098128],
#                 {
# }
#             ).addTo(map_3ceacb0480bdd5d228ae800f58aa661b);
#
#
#             var icon_9fdd4d55e54ab8610165311caa4a6560 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c8efc17ff9bd491f9f30aafddc749bae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c33e690c1077d91d86ec0e78a568189f = $(`&lt;div id=&quot;html_c33e690c1077d91d86ec0e78a568189f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; 5.0&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; 1200.0&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; 1200.0&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; 1150.0&lt;/div&gt;`)[0];
#                 popup_c8efc17ff9bd491f9f30aafddc749bae.setContent(html_c33e690c1077d91d86ec0e78a568189f);
#
#
#
#         marker_0fc89efa827f96f2ea9908153e02e5ef.bindPopup(popup_c8efc17ff9bd491f9f30aafddc749bae)
#         ;
#
#
#
#
#             marker_0fc89efa827f96f2ea9908153e02e5ef.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Customer 1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_0fc89efa827f96f2ea9908153e02e5ef.setIcon(icon_9fdd4d55e54ab8610165311caa4a6560);
#
#
#             var marker_460564b6c5145b805772a37e119c1682 = L.marker(
#                 [35.6101355, -108.5282439],
#                 {
# }
#             ).addTo(map_3ceacb0480bdd5d228ae800f58aa661b);
#
#
#             var icon_68e6dfab2b4c8b050ffe76a0faea7e91 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;beige&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8f3fc0aa3636095378191c2a60ee1abb = L.

# %%
### Time 3

# Load the data from excel sheet
time3 = pd.read_excel("Subsets_Afreen.xlsx", engine="openpyxl", sheet_name="Time 3")

#convert to csv file 
time3.to_csv("Time 3.csv",index=False)

# read csv file
time3_df = pd.read_csv("Time 3.csv", header=0)

# clean data
time3_df.columns = time3_df.columns.str.strip()

# list of tuples that zips together each row household's data with the following columns
coords = list(zip(time3_df['Latitude'], time3_df['Longitude'], 
                  time3_df['Preferred ID'], time3_df['Household size'], 
                  time3_df['Capacity'], time3_df['Delivery Amount'], 
                  time3_df['Inventory'], time3_df['Code for water storage tank']))

# plot on map
time3_m = folium.Map(tiles='OpenStreetMap')

# assign color based on water tank code
def get_color(water_tank_code):
    color_mapping = {
        1200: 'blue',
        275: 'red',
        1000: 'beige',
        1475: 'purple',
        1275: 'orange',
        2200: 'green',
        2475: 'lightgray',
        2000: 'lightgreen',
        3200: 'cadetblue'  
    }
    return color_mapping.get(water_tank_code, 'black')  # black for office and water depots  

# markers colored based on water tank code with popup and hover 
for lat, lon, id, household_size, capacity, delivery_amount, inventory, water_tank_code in coords:
    color = get_color(water_tank_code)
    folium.Marker(
        [lat, lon],
        icon=folium.Icon(color=color),
        tooltip=f"Preferred ID: {id}",  # tooltip for hover
        popup=( 
            f"<b>Household Size:</b> {household_size}<br>"
            f"<b>Capacity:</b> {capacity}<br>"
            f"<b>Delivery Amount:</b> {delivery_amount}<br>"
            f"<b>Inventory:</b> {inventory}"  
        )  # popup for click
    ).add_to(time3_m)

# southwestern US 
sw = [35.3, -108]  
ne = [35.65, -109]  
time3_m.fit_bounds([sw, ne])

# coordinates for line paths between households 
coordinates = [
    [35.407167, -108.234917],
    [35.32923797, -108.8098128],
    [35.46312211, -108.9559325],
    [35.407167, -108.234917]
]

# Add Polyline to the Map
folium.PolyLine(
    locations=coordinates,  
    color="black",         
    weight=3,               
    opacity=0.7            
).add_to(time3_m)

# loop to add segment labels 
for i in range(len(coordinates) - 1):
    lat1, lon1 = coordinates[i]
    lat2, lon2 = coordinates[i + 1]
    
    # Calculate midpoint
    mid_lat = (lat1 + lat2) / 2
    mid_lon = (lon1 + lon2) / 2

    # Add marker with segment number
    folium.Marker(
        location=[mid_lat, mid_lon],
        icon=folium.DivIcon(html=f'''
                <div style="
                    font-size: 12pt; 
                    font-weight: bold; 
                    color: black; 
                    background-color: white;
                    padding: 2px; 
                    border-radius: 5px;
                    text-align: center;
                ">
                    {i + 1}
                </div>
            '''),
            tooltip=f"Segment {i + 1}"
    ).add_to(time3_m)

# add title to map
title_html = """
<h3 align="center" style="font-size:24px; margin-top:10px;">
    Route - Time 3
</h3>
"""
time3_m.get_root().html.add_child(Element(title_html))

# save to HTML file
time3_m.save("Time3.html")
time3_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6688904fa6187ad4fa2c35a1ffff1cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;h3 align=&quot;center&quot; style=&quot;font-size:24px; margin-top:10px;&quot;&gt;
#     Route - Time 3
# &lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6688904fa6187ad4fa2c35a1ffff1cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6688904fa6187ad4fa2c35a1ffff1cf = L.map(
#                 &quot;map_a6688904fa6187ad4fa2c35a1ffff1cf&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70a4a5b95ab85e1f926451774a31a21e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70a4a5b95ab85e1f926451774a31a21e.addTo(map_a6688904fa6187ad4fa2c35a1ffff1cf);
#
#
#             var marker_acfd4b3d7544452261ca09a99004dfcd = L.marker(
#                 [35.407167, -108.234917],
#                 {
# }
#             ).addTo(map_a6688904fa6187ad4fa2c35a1ffff1cf);
#
#
#             var icon_5cb3aa1673d4200de32318cba06489c3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9d30382cf10ba60de1986988f7f74573 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83a3c1a0716cb7d79be7d7a02e3c3cf4 = $(`&lt;div id=&quot;html_83a3c1a0716cb7d79be7d7a02e3c3cf4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; nan&lt;/div&gt;`)[0];
#                 popup_9d30382cf10ba60de1986988f7f74573.setContent(html_83a3c1a0716cb7d79be7d7a02e3c3cf4);
#
#
#
#         marker_acfd4b3d7544452261ca09a99004dfcd.bindPopup(popup_9d30382cf10ba60de1986988f7f74573)
#         ;
#
#
#
#
#             marker_acfd4b3d7544452261ca09a99004dfcd.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Depot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_acfd4b3d7544452261ca09a99004dfcd.setIcon(icon_5cb3aa1673d4200de32318cba06489c3);
#
#
#             var marker_9005df098f0cfd5486e965e4ad86930b = L.marker(
#                 [35.32923797, -108.8098128],
#                 {
# }
#             ).addTo(map_a6688904fa6187ad4fa2c35a1ffff1cf);
#
#
#             var icon_8243b30c388b33a047288e235dc28510 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e3492f22723c7d360208f08ffbc77263 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13743a17695bf2b0b929412dd7970aa5 = $(`&lt;div id=&quot;html_13743a17695bf2b0b929412dd7970aa5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; 5.0&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; 1200.0&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; 1200.0&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; 1150.0&lt;/div&gt;`)[0];
#                 popup_e3492f22723c7d360208f08ffbc77263.setContent(html_13743a17695bf2b0b929412dd7970aa5);
#
#
#
#         marker_9005df098f0cfd5486e965e4ad86930b.bindPopup(popup_e3492f22723c7d360208f08ffbc77263)
#         ;
#
#
#
#
#             marker_9005df098f0cfd5486e965e4ad86930b.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Customer 1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_9005df098f0cfd5486e965e4ad86930b.setIcon(icon_8243b30c388b33a047288e235dc28510);
#
#
#             var marker_bbe82b1c5e3b5d342c82d0b384628c25 = L.marker(
#                 [35.6101355, -108.5282439],
#                 {
# }
#             ).addTo(map_a6688904fa6187ad4fa2c35a1ffff1cf);
#
#
#             var icon_198dd7915d265dfc745154c82e397ed6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;beige&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_86746063444624cef819f096a7546f79 = L.

# %%
### NN Time 1

# Load the data from excel sheet
NNtime1 = pd.read_excel("Subsets_Afreen.xlsx", engine="openpyxl", sheet_name="NN Time 1")

# convert to csv file 
NNtime1.to_csv("NN Time 1.csv",index=False)

# read csv file 
NNtime1_df = pd.read_csv("NN Time 1.csv", header=0)

# clean data 
NNtime1_df.columns = NNtime1_df.columns.str.strip()

# list of tuples that zips together each row household's data with the following columns
coords = list(zip(NNtime1_df['Latitude'], NNtime1_df['Longitude'], 
                  NNtime1_df['Preferred ID'], NNtime1_df['Household size'], 
                  NNtime1_df['Capacity'], NNtime1_df['Delivery Amount'], 
                  NNtime1_df['Inventory'], NNtime1_df['Code for water storage tank']))

# plot on map
NNtime1_m = folium.Map(tiles='OpenStreetMap')

# assign color based on water tank code
def get_color(water_tank_code):
    color_mapping = {
        1200: 'blue',
        275: 'red',
        1000: 'beige',
        1475: 'purple',
        1275: 'orange',
        2200: 'green',
        2475: 'lightgray',
        2000: 'lightgreen',
        3200: 'cadetblue'  
    }
    return color_mapping.get(water_tank_code, 'black')  # black for office and water depots 

# markers colored based on water tank code with popup and hover 
for lat, lon, id, household_size, capacity, delivery_amount, inventory, water_tank_code in coords:
    color = get_color(water_tank_code)
    folium.Marker(
        [lat, lon],
        icon=folium.Icon(color=color),
        tooltip=f"Preferred ID: {id}",  # tooltip for hover
        popup=( 
            f"<b>Household Size:</b> {household_size}<br>"
            f"<b>Capacity:</b> {capacity}<br>"
            f"<b>Delivery Amount:</b> {delivery_amount}<br>"
            f"<b>Inventory:</b> {inventory}"  
        )  # popup for click
    ).add_to(NNtime1_m)

# southwestern US 
sw = [35.3, -108]  
ne = [35.65, -109]  
NNtime1_m.fit_bounds([sw, ne])

# 2 lists of coordinates for line paths between households for 2 different routes 
coordinates = [
    [(35.407167, -108.234917),
    (35.32923797, -108.8098128),
    (35.46312211, -108.9559325),
    (35.6101355, -108.5282439),
    (35.47805444, -108.3411384),
    (35.407167, -108.234917)],
    
    [(35.407167, -108.234917),
    (35.29681843, -108.0062987),
    (35.36235925, -107.968078),
    (35.36601699, -108.0755568),
    (35.407167, -108.234917)]
]

# 2 different colros for both routes 
colors = ['purple', 'green']

# loop to add segment labels 
for points, color in zip(coordinates, colors):
    folium.PolyLine(points, color=color, weight=3, opacity=0.7).add_to(NNtime1_m)

    for i in range(len(points) - 1):
        lat1, lon1 = points[i]
        lat2, lon2 = points[i + 1]

        # Compute midpoint
        mid_lat = (lat1 + lat2) / 2
        mid_lon = (lon1 + lon2) / 2

        # Add segment number above the line
        folium.Marker(
            location=[mid_lat, mid_lon],
            icon=folium.DivIcon(html=f'''
                <div style="
                    font-size: 12pt; 
                    font-weight: bold; 
                    color: black; 
                    background-color: white;
                    padding: 2px; 
                    border-radius: 5px;
                    text-align: center;
                ">
                    {i + 1}
                </div>
            '''),
            tooltip=f"Segment {i + 1}"
        ).add_to(NNtime1_m)

# add title to map
title_html = """
<h3 align="center" style="font-size:24px; margin-top:10px;">
    Routes - NN Time 1
</h3>
"""
NNtime1_m.get_root().html.add_child(Element(title_html))

# save to HTML file
NNtime1_m.save("NN Time1.html")
NNtime1_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_786805b2a111a28f4329e8da78ac460d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;h3 align=&quot;center&quot; style=&quot;font-size:24px; margin-top:10px;&quot;&gt;
#     Routes - NN Time 1
# &lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_786805b2a111a28f4329e8da78ac460d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_786805b2a111a28f4329e8da78ac460d = L.map(
#                 &quot;map_786805b2a111a28f4329e8da78ac460d&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5248828938d252a86c2acc40978bfcc2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5248828938d252a86c2acc40978bfcc2.addTo(map_786805b2a111a28f4329e8da78ac460d);
#
#
#             var marker_7a2a3f6b54baede8e9c066f0e10e0967 = L.marker(
#                 [35.407167, -108.234917],
#                 {
# }
#             ).addTo(map_786805b2a111a28f4329e8da78ac460d);
#
#
#             var icon_5f0df75ecd06c567bb60b569b272a838 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5078fb4842770c5976ca80be0615cdab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31379fa6e7cac2de896d7f2b10d8c947 = $(`&lt;div id=&quot;html_31379fa6e7cac2de896d7f2b10d8c947&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; nan&lt;/div&gt;`)[0];
#                 popup_5078fb4842770c5976ca80be0615cdab.setContent(html_31379fa6e7cac2de896d7f2b10d8c947);
#
#
#
#         marker_7a2a3f6b54baede8e9c066f0e10e0967.bindPopup(popup_5078fb4842770c5976ca80be0615cdab)
#         ;
#
#
#
#
#             marker_7a2a3f6b54baede8e9c066f0e10e0967.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Depot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_7a2a3f6b54baede8e9c066f0e10e0967.setIcon(icon_5f0df75ecd06c567bb60b569b272a838);
#
#
#             var marker_fadd8076bf266351ac2add9ac9b4b02a = L.marker(
#                 [35.32923797, -108.8098128],
#                 {
# }
#             ).addTo(map_786805b2a111a28f4329e8da78ac460d);
#
#
#             var icon_288f76b59aa158d5a252003a405655cf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0fbd20ad00714fbe776392e1817580ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d529dfff5c1511bce3e95dda2c9776a = $(`&lt;div id=&quot;html_6d529dfff5c1511bce3e95dda2c9776a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; 5.0&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; 1200.0&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; 1200.0&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; 1150.0&lt;/div&gt;`)[0];
#                 popup_0fbd20ad00714fbe776392e1817580ed.setContent(html_6d529dfff5c1511bce3e95dda2c9776a);
#
#
#
#         marker_fadd8076bf266351ac2add9ac9b4b02a.bindPopup(popup_0fbd20ad00714fbe776392e1817580ed)
#         ;
#
#
#
#
#             marker_fadd8076bf266351ac2add9ac9b4b02a.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Customer 1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_fadd8076bf266351ac2add9ac9b4b02a.setIcon(icon_288f76b59aa158d5a252003a405655cf);
#
#
#             var marker_068cdd88c25acf62899bc8552ea5b6d1 = L.marker(
#                 [35.6101355, -108.5282439],
#                 {
# }
#             ).addTo(map_786805b2a111a28f4329e8da78ac460d);
#
#
#             var icon_87c7b7e9dbd216758d1e2b453dd9509c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;beige&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ba0761bfec9e5d733bf7bc54c9288e2e

# %%
### NN Time 4

# Load the data from excel sheet
NNtime4 = pd.read_excel("Subsets_Afreen.xlsx", engine="openpyxl", sheet_name="NN Time 4")

# convert to csv file 
NNtime4.to_csv("NN Time 4.csv",index=False)

# read csv file 
NNtime4_df = pd.read_csv("NN Time 4.csv", header=0)

# clean data
NNtime4_df.columns = NNtime1_df.columns.str.strip()

# list of tuples that zips together each row household's data with the following columns
coords = list(zip(NNtime4_df['Latitude'], NNtime4_df['Longitude'], 
                  NNtime4_df['Preferred ID'], NNtime4_df['Household size'], 
                  NNtime4_df['Capacity'], NNtime4_df['Delivery Amount'], 
                  NNtime4_df['Inventory'], NNtime4_df['Code for water storage tank']))

# plot on map
NNtime4_m = folium.Map(tiles='OpenStreetMap')

# assign color based on water tank code
def get_color(water_tank_code):
    color_mapping = {
        1200: 'blue',
        275: 'red',
        1000: 'beige',
        1475: 'purple',
        1275: 'orange',
        2200: 'green',
        2475: 'lightgray',
        2000: 'lightgreen',
        3200: 'cadetblue'  
    }
    return color_mapping.get(water_tank_code, 'black')  # black for the other 3 left 

# markers colored based on water tank code with popup and hover 
for lat, lon, id, household_size, capacity, delivery_amount, inventory, water_tank_code in coords:
    color = get_color(water_tank_code)
    folium.Marker(
        [lat, lon],
        icon=folium.Icon(color=color),
        tooltip=f"Preferred ID: {id}",  # tooltip for hover
        popup=( 
            f"<b>Household Size:</b> {household_size}<br>"
            f"<b>Capacity:</b> {capacity}<br>"
            f"<b>Delivery Amount:</b> {delivery_amount}<br>"
            f"<b>Inventory:</b> {inventory}"  
        )  # popup for click
    ).add_to(NNtime4_m)

# southwestern US 
sw = [35.3, -108]  
ne = [35.65, -109]  
NNtime4_m.fit_bounds([sw, ne])

# coordinates for line paths between households 
coordinates = [
    [35.407167, -108.234917],
    [35.29681843, -108.0062987],
    [35.36235925, -107.968078],
    [35.36601699, -108.0755568],
    [35.407167, -108.234917]
]

# Add Polyline to the Map
folium.PolyLine(
    locations=coordinates,  
    color="black",         
    weight=3,               
    opacity=0.7            
).add_to(NNtime4_m)

# loop to add segment labels 
for i in range(len(coordinates) - 1):
    lat1, lon1 = coordinates[i]
    lat2, lon2 = coordinates[i + 1]
    
    # Calculate midpoint
    mid_lat = (lat1 + lat2) / 2
    mid_lon = (lon1 + lon2) / 2

    # Add marker with segment number
    folium.Marker(
        location=[mid_lat, mid_lon],
        icon=folium.DivIcon(html=f'''
                <div style="
                    font-size: 12pt; 
                    font-weight: bold; 
                    color: black; 
                    background-color: white;
                    padding: 2px; 
                    border-radius: 5px;
                    text-align: center;
                ">
                    {i + 1}
                </div>
            '''),
            tooltip=f"Segment {i + 1}"
    ).add_to(NNtime4_m)

# add title to map
title_html = """
<h3 align="center" style="font-size:24px; margin-top:10px;">
    Route - NN Time 4
</h3>
"""
NNtime4_m.get_root().html.add_child(Element(title_html))

# save to HTML file
NNtime4_m.save("NN Time4.html")
NNtime4_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8afd3fde8767394d500145a8eea7d2ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;h3 align=&quot;center&quot; style=&quot;font-size:24px; margin-top:10px;&quot;&gt;
#     Route - NN Time 4
# &lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8afd3fde8767394d500145a8eea7d2ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8afd3fde8767394d500145a8eea7d2ba = L.map(
#                 &quot;map_8afd3fde8767394d500145a8eea7d2ba&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1001aa24ae5377ebcf12cb0cafd5c09 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f1001aa24ae5377ebcf12cb0cafd5c09.addTo(map_8afd3fde8767394d500145a8eea7d2ba);
#
#
#             var marker_2fe079b48ff2434bac5aa3bec2af7109 = L.marker(
#                 [35.407167, -108.234917],
#                 {
# }
#             ).addTo(map_8afd3fde8767394d500145a8eea7d2ba);
#
#
#             var icon_b29afd34b2c19c3bdc725836ad3b1727 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_18003e5f906829cf250fe3a5badbdb73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c48f5047175791823e3d9066751f31a = $(`&lt;div id=&quot;html_3c48f5047175791823e3d9066751f31a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; nan&lt;/div&gt;`)[0];
#                 popup_18003e5f906829cf250fe3a5badbdb73.setContent(html_3c48f5047175791823e3d9066751f31a);
#
#
#
#         marker_2fe079b48ff2434bac5aa3bec2af7109.bindPopup(popup_18003e5f906829cf250fe3a5badbdb73)
#         ;
#
#
#
#
#             marker_2fe079b48ff2434bac5aa3bec2af7109.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Depot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_2fe079b48ff2434bac5aa3bec2af7109.setIcon(icon_b29afd34b2c19c3bdc725836ad3b1727);
#
#
#             var marker_e6a1e576b39424ee0fd6bb7bfa7e516e = L.marker(
#                 [35.32923797, -108.8098128],
#                 {
# }
#             ).addTo(map_8afd3fde8767394d500145a8eea7d2ba);
#
#
#             var icon_cb2d4f764014004759515d08038ba3c8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3d8118dd66fae7b25f06fdf36218dbea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bd20b551fdc3c1240f9b2dfa0f5fa5a = $(`&lt;div id=&quot;html_9bd20b551fdc3c1240f9b2dfa0f5fa5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; 5.0&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; 1200.0&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; 0.0&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; 1000.0&lt;/div&gt;`)[0];
#                 popup_3d8118dd66fae7b25f06fdf36218dbea.setContent(html_9bd20b551fdc3c1240f9b2dfa0f5fa5a);
#
#
#
#         marker_e6a1e576b39424ee0fd6bb7bfa7e516e.bindPopup(popup_3d8118dd66fae7b25f06fdf36218dbea)
#         ;
#
#
#
#
#             marker_e6a1e576b39424ee0fd6bb7bfa7e516e.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Customer 1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_e6a1e576b39424ee0fd6bb7bfa7e516e.setIcon(icon_cb2d4f764014004759515d08038ba3c8);
#
#
#             var marker_e3439e382bcee80593aee3aaf7b8447c = L.marker(
#                 [35.6101355, -108.5282439],
#                 {
# }
#             ).addTo(map_8afd3fde8767394d500145a8eea7d2ba);
#
#
#             var icon_f142a97007d420956e198e607f8feb3e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;beige&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7bbbea82e3e9ecdeef0a335f59070296 = L.
