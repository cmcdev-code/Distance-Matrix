# %%
from folium import Map, Marker, Icon, Element
import pandas as pd 

### Time 0

# Load the data from excel sheet
time0 = pd.read_excel("Subsets_Afreen.xlsx", engine="openpyxl", sheet_name="Time 0")

# convert to csv file 
time0.to_csv("Time 0.csv",index=False)

# read csv file 
time0_df = pd.read_csv("Time 0.csv", header=0)

#clean data 
time0_df.columns = time0_df.columns.str.strip()

# list of tuples that zips together each row household's data with the following columns
coords = list(zip(time0_df['Latitude'], time0_df['Longitude'], 
                  time0_df['Preferred ID'], time0_df['Household size'], 
                  time0_df['Capacity'], time0_df['Delivery Amount'], 
                  time0_df['Inventory'], time0_df['Code for water storage tank']))
# plot on map
time0_m = folium.Map(tiles='OpenStreetMap')

# assign color based on water tank code
def get_color(water_tank_code):
    color_mapping = {
        1200: 'blue',
        275: 'red',
        1000: 'beige',
        1475: 'purple',
        1275: 'orange',
        2200: 'green',
        2475: 'lightgray',
        2000: 'lightgreen',
        3200: 'cadetblue'  
    }
    return color_mapping.get(water_tank_code, 'black')  # black for office and water depots  

# markers colored based on water tank code with popup and hover 
for lat, lon, id, household_size, capacity, delivery_amount, inventory, water_tank_code in coords:
    color = get_color(water_tank_code)
    folium.Marker(
        [lat, lon],
        icon=folium.Icon(color=color),
        tooltip=f"Preferred ID: {id}",  # tooltip for hover
        popup=( 
            f"<b>Household Size:</b> {household_size}<br>"
            f"<b>Capacity:</b> {capacity}<br>"
            f"<b>Delivery Amount:</b> {delivery_amount}<br>"
            f"<b>Inventory:</b> {inventory}"  
        )  # popup for click
    ).add_to(time0_m)

# coordinates to recenter map around zoomed in region 
sw = [35.3, -108]  
ne = [35.65, -109]  
time0_m.fit_bounds([sw, ne])

# add title to map
title_html = """
<h3 align="center" style="font-size:24px; margin-top:10px;">
    Route - Time 0
</h3>
"""
time0_m.get_root().html.add_child(Element(title_html))

# save to HTML file
time0_m.save("Time0.html")
time0_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb78cc50593ca531eaba1c4fffd1c6d0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;h3 align=&quot;center&quot; style=&quot;font-size:24px; margin-top:10px;&quot;&gt;
#     Route - Time 0
# &lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb78cc50593ca531eaba1c4fffd1c6d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb78cc50593ca531eaba1c4fffd1c6d0 = L.map(
#                 &quot;map_cb78cc50593ca531eaba1c4fffd1c6d0&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6b1d0710e079a432735ead9c8fdec11 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cb78cc50593ca531eaba1c4fffd1c6d0);
#
#
#             var marker_b5e97acfc9852432aa40a0b38732f518 = L.marker(
#                 [35.407167, -108.234917],
#                 {}
#             ).addTo(map_cb78cc50593ca531eaba1c4fffd1c6d0);
#
#
#             var icon_9241d649f27611214110e80d37d15319 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b5e97acfc9852432aa40a0b38732f518.setIcon(icon_9241d649f27611214110e80d37d15319);
#
#
#         var popup_3ccca96718df7387cb4a7c8d8bcb31a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_744e34814a1e86775f6ffc29a0abb674 = $(`&lt;div id=&quot;html_744e34814a1e86775f6ffc29a0abb674&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; nan&lt;/div&gt;`)[0];
#                 popup_3ccca96718df7387cb4a7c8d8bcb31a5.setContent(html_744e34814a1e86775f6ffc29a0abb674);
#
#
#
#         marker_b5e97acfc9852432aa40a0b38732f518.bindPopup(popup_3ccca96718df7387cb4a7c8d8bcb31a5)
#         ;
#
#
#
#
#             marker_b5e97acfc9852432aa40a0b38732f518.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Depot
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_26b834e9d348e1a5f420668a8c319caa = L.marker(
#                 [35.32923797, -108.8098128],
#                 {}
#             ).addTo(map_cb78cc50593ca531eaba1c4fffd1c6d0);
#
#
#             var icon_bb6c96335e8adfce5e7b4b17c6480cf6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_26b834e9d348e1a5f420668a8c319caa.setIcon(icon_bb6c96335e8adfce5e7b4b17c6480cf6);
#
#
#         var popup_33a061cc027075ff5987c1d762a311a9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_72f5d106ac98dda8221b89b9b642f428 = $(`&lt;div id=&quot;html_72f5d106ac98dda8221b89b9b642f428&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; 5.0&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; 1200.0&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; 0.0&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; 0.0&lt;/div&gt;`)[0];
#                 popup_33a061cc027075ff5987c1d762a311a9.setContent(html_72f5d106ac98dda8221b89b9b642f428);
#
#
#
#         marker_26b834e9d348e1a5f420668a8c319caa.bindPopup(popup_33a061cc027075ff5987c1d762a311a9)
#         ;
#
#
#
#
#             marker_26b834e9d348e1a5f420668a8c319caa.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Customer 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d6228f22b1a8557e94839ca2c3ed5236 = L.marker(
#                 [35.6101355, -108.5282439],
#                 {}
#             ).addTo(map_cb78cc50593ca531eaba1c4fffd1c6d0);
#
#
#             var icon_8d8dfc181055e8a4400a5162f380bd96 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d6228f22b1a8557e94839ca2c3ed5236.setIcon(icon_8d8dfc181055e8a4400a5162f380bd96);
#
#
#         var popup_914c0515c76a367675ac0460

# %%
### Time 1

# Load the data from excel sheet
time1 = pd.read_excel("Subsets_Afreen.xlsx", engine="openpyxl", sheet_name="Time 1")

# convert to csv file 
time1.to_csv("Time 1.csv",index=False)

# read csv file 
time1_df = pd.read_csv("Time 1.csv", header=0)

# clean data
time1_df.columns = time0_df.columns.str.strip()

# list of tuples that zips together each row household's data with the following columns
coords = list(zip(time1_df['Latitude'], time1_df['Longitude'], 
                  time1_df['Preferred ID'], time1_df['Household size'], 
                  time1_df['Capacity'], time1_df['Delivery Amount'], 
                  time1_df['Inventory'], time1_df['Code for water storage tank']))

# plot on map
time1_m = folium.Map(tiles='OpenStreetMap')

# assign color based on water tank code
def get_color(water_tank_code):
    color_mapping = {
        1200: 'blue',
        275: 'red',
        1000: 'beige',
        1475: 'purple',
        1275: 'orange',
        2200: 'green',
        2475: 'lightgray',
        2000: 'lightgreen',
        3200: 'cadetblue'  
    }
    return color_mapping.get(water_tank_code, 'black')  # black for office and water depots 

# markers colored based on water tank code with popup and hover 
for lat, lon, id, household_size, capacity, delivery_amount, inventory, water_tank_code in coords:
    color = get_color(water_tank_code)
    folium.Marker(
        [lat, lon],
        icon=folium.Icon(color=color),
        tooltip=f"Preferred ID: {id}",  # tooltip for hover
        popup=( 
            f"<b>Household Size:</b> {household_size}<br>"
            f"<b>Capacity:</b> {capacity}<br>"
            f"<b>Delivery Amount:</b> {delivery_amount}<br>"
            f"<b>Inventory:</b> {inventory}"  
        )  # popup for click
    ).add_to(time1_m)

# southwestern US 
sw = [35.3, -108]  
ne = [35.65, -109]  
time1_m.fit_bounds([sw, ne])

# coordinates for line paths between households 
coordinates = [
    [35.407167, -108.234917],
    [35.32923797, -108.8098128],
    [35.46312211, -108.9559325],
    [35.6101355, -108.5282439],
    [35.36235925, -107.968078],
    [35.36601699, -108.0755568],
    [35.407167, -108.234917]
]

# Add Polyline to the Map
folium.PolyLine(
    locations=coordinates,  
    color="black",         
    weight=3,               
    opacity=0.7            
).add_to(time1_m)

# loop to add segment labels 
for i in range(len(coordinates) - 1):
    lat1, lon1 = coordinates[i]
    lat2, lon2 = coordinates[i + 1]
    
    # Calculate midpoint
    mid_lat = (lat1 + lat2) / 2
    mid_lon = (lon1 + lon2) / 2

    # Add marker with segment number
    folium.Marker(
        location=[mid_lat, mid_lon],
        icon=folium.DivIcon(html=f'''
                <div style="
                    font-size: 12pt; 
                    font-weight: bold; 
                    color: black; 
                    background-color: white;
                    padding: 2px; 
                    border-radius: 5px;
                    text-align: center;
                ">
                    {i + 1}
                </div>
            '''),
            tooltip=f"Segment {i + 1}"
    ).add_to(time1_m)

# add title to map
title_html = """
<h3 align="center" style="font-size:24px; margin-top:10px;">
    Route - Time 1
</h3>
"""
time1_m.get_root().html.add_child(Element(title_html))

# save to HTML file
time1_m.save("Time1.html")
time1_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c0e508406a5f94562a294ce6667e19f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;h3 align=&quot;center&quot; style=&quot;font-size:24px; margin-top:10px;&quot;&gt;
#     Route - Time 1
# &lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c0e508406a5f94562a294ce6667e19f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c0e508406a5f94562a294ce6667e19f = L.map(
#                 &quot;map_1c0e508406a5f94562a294ce6667e19f&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d21d156de9ecb1333f60138850c735a7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1c0e508406a5f94562a294ce6667e19f);
#
#
#             var marker_ab24b8920faa99d39414c8e11162f0f9 = L.marker(
#                 [35.407167, -108.234917],
#                 {}
#             ).addTo(map_1c0e508406a5f94562a294ce6667e19f);
#
#
#             var icon_0a720cf2c22b250829d029a3e9361e8c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ab24b8920faa99d39414c8e11162f0f9.setIcon(icon_0a720cf2c22b250829d029a3e9361e8c);
#
#
#         var popup_aa738f05db51ab84fe7d1e2d68edd0f5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_897e91bf820af7b2df976bee5c3caaa1 = $(`&lt;div id=&quot;html_897e91bf820af7b2df976bee5c3caaa1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; nan&lt;/div&gt;`)[0];
#                 popup_aa738f05db51ab84fe7d1e2d68edd0f5.setContent(html_897e91bf820af7b2df976bee5c3caaa1);
#
#
#
#         marker_ab24b8920faa99d39414c8e11162f0f9.bindPopup(popup_aa738f05db51ab84fe7d1e2d68edd0f5)
#         ;
#
#
#
#
#             marker_ab24b8920faa99d39414c8e11162f0f9.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Depot
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_587335be78d1c8483116df271f00b5c1 = L.marker(
#                 [35.32923797, -108.8098128],
#                 {}
#             ).addTo(map_1c0e508406a5f94562a294ce6667e19f);
#
#
#             var icon_f573b2060dabcde61ceef7f922d4ff86 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_587335be78d1c8483116df271f00b5c1.setIcon(icon_f573b2060dabcde61ceef7f922d4ff86);
#
#
#         var popup_1e5af1cdb5e32a753010f99596b983c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8703c69b301d8c40fba872630b7937c8 = $(`&lt;div id=&quot;html_8703c69b301d8c40fba872630b7937c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; 5.0&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; 1200.0&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; 1200.0&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; 1150.0&lt;/div&gt;`)[0];
#                 popup_1e5af1cdb5e32a753010f99596b983c1.setContent(html_8703c69b301d8c40fba872630b7937c8);
#
#
#
#         marker_587335be78d1c8483116df271f00b5c1.bindPopup(popup_1e5af1cdb5e32a753010f99596b983c1)
#         ;
#
#
#
#
#             marker_587335be78d1c8483116df271f00b5c1.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Customer 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8b32cb5b5f183a9d20ffbadf48d10813 = L.marker(
#                 [35.6101355, -108.5282439],
#                 {}
#             ).addTo(map_1c0e508406a5f94562a294ce6667e19f);
#
#
#             var icon_8bdedb898bbcb6e704221738e178a3c4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8b32cb5b5f183a9d20ffbadf48d10813.setIcon(icon_8bdedb898bbcb6e704221738e178a3c4);
#
#
#         var popup_dda52de81d6acb1de8

# %%
### Time 3

# Load the data from excel sheet
time3 = pd.read_excel("Subsets_Afreen.xlsx", engine="openpyxl", sheet_name="Time 3")

#convert to csv file 
time3.to_csv("Time 3.csv",index=False)

# read csv file
time3_df = pd.read_csv("Time 3.csv", header=0)

# clean data
time3_df.columns = time3_df.columns.str.strip()

# list of tuples that zips together each row household's data with the following columns
coords = list(zip(time3_df['Latitude'], time3_df['Longitude'], 
                  time3_df['Preferred ID'], time3_df['Household size'], 
                  time3_df['Capacity'], time3_df['Delivery Amount'], 
                  time3_df['Inventory'], time3_df['Code for water storage tank']))

# plot on map
time3_m = folium.Map(tiles='OpenStreetMap')

# assign color based on water tank code
def get_color(water_tank_code):
    color_mapping = {
        1200: 'blue',
        275: 'red',
        1000: 'beige',
        1475: 'purple',
        1275: 'orange',
        2200: 'green',
        2475: 'lightgray',
        2000: 'lightgreen',
        3200: 'cadetblue'  
    }
    return color_mapping.get(water_tank_code, 'black')  # black for office and water depots  

# markers colored based on water tank code with popup and hover 
for lat, lon, id, household_size, capacity, delivery_amount, inventory, water_tank_code in coords:
    color = get_color(water_tank_code)
    folium.Marker(
        [lat, lon],
        icon=folium.Icon(color=color),
        tooltip=f"Preferred ID: {id}",  # tooltip for hover
        popup=( 
            f"<b>Household Size:</b> {household_size}<br>"
            f"<b>Capacity:</b> {capacity}<br>"
            f"<b>Delivery Amount:</b> {delivery_amount}<br>"
            f"<b>Inventory:</b> {inventory}"  
        )  # popup for click
    ).add_to(time3_m)

# southwestern US 
sw = [35.3, -108]  
ne = [35.65, -109]  
time3_m.fit_bounds([sw, ne])

# coordinates for line paths between households 
coordinates = [
    [35.407167, -108.234917],
    [35.32923797, -108.8098128],
    [35.46312211, -108.9559325],
    [35.407167, -108.234917]
]

# Add Polyline to the Map
folium.PolyLine(
    locations=coordinates,  
    color="black",         
    weight=3,               
    opacity=0.7            
).add_to(time3_m)

# loop to add segment labels 
for i in range(len(coordinates) - 1):
    lat1, lon1 = coordinates[i]
    lat2, lon2 = coordinates[i + 1]
    
    # Calculate midpoint
    mid_lat = (lat1 + lat2) / 2
    mid_lon = (lon1 + lon2) / 2

    # Add marker with segment number
    folium.Marker(
        location=[mid_lat, mid_lon],
        icon=folium.DivIcon(html=f'''
                <div style="
                    font-size: 12pt; 
                    font-weight: bold; 
                    color: black; 
                    background-color: white;
                    padding: 2px; 
                    border-radius: 5px;
                    text-align: center;
                ">
                    {i + 1}
                </div>
            '''),
            tooltip=f"Segment {i + 1}"
    ).add_to(time3_m)

# add title to map
title_html = """
<h3 align="center" style="font-size:24px; margin-top:10px;">
    Route - Time 3
</h3>
"""
time3_m.get_root().html.add_child(Element(title_html))

# save to HTML file
time3_m.save("Time3.html")
time3_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba0ed9f858085aa5d0e18246bfe77bf8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;h3 align=&quot;center&quot; style=&quot;font-size:24px; margin-top:10px;&quot;&gt;
#     Route - Time 3
# &lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba0ed9f858085aa5d0e18246bfe77bf8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba0ed9f858085aa5d0e18246bfe77bf8 = L.map(
#                 &quot;map_ba0ed9f858085aa5d0e18246bfe77bf8&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_29c267ccebab91b6295198931e39c9d8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ba0ed9f858085aa5d0e18246bfe77bf8);
#
#
#             var marker_a72feb898813777ea377e7f37cedf15e = L.marker(
#                 [35.407167, -108.234917],
#                 {}
#             ).addTo(map_ba0ed9f858085aa5d0e18246bfe77bf8);
#
#
#             var icon_99947288dce01a3399a7318b9ba3164e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a72feb898813777ea377e7f37cedf15e.setIcon(icon_99947288dce01a3399a7318b9ba3164e);
#
#
#         var popup_6c20ca4f1041c8e18b9419cf55794ece = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd3c71a8a3269e84d577e87057c78df3 = $(`&lt;div id=&quot;html_fd3c71a8a3269e84d577e87057c78df3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; nan&lt;/div&gt;`)[0];
#                 popup_6c20ca4f1041c8e18b9419cf55794ece.setContent(html_fd3c71a8a3269e84d577e87057c78df3);
#
#
#
#         marker_a72feb898813777ea377e7f37cedf15e.bindPopup(popup_6c20ca4f1041c8e18b9419cf55794ece)
#         ;
#
#
#
#
#             marker_a72feb898813777ea377e7f37cedf15e.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Depot
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_92fe43d7126f3c589c967e9c49a97832 = L.marker(
#                 [35.32923797, -108.8098128],
#                 {}
#             ).addTo(map_ba0ed9f858085aa5d0e18246bfe77bf8);
#
#
#             var icon_0af417002e7a8bfeaa13f9e182249514 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_92fe43d7126f3c589c967e9c49a97832.setIcon(icon_0af417002e7a8bfeaa13f9e182249514);
#
#
#         var popup_4bbc54f1a99fa3befe416823a46d4ba4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d254b1bc9717fe5074e1a19f6397d5c1 = $(`&lt;div id=&quot;html_d254b1bc9717fe5074e1a19f6397d5c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; 5.0&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; 1200.0&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; 1200.0&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; 1150.0&lt;/div&gt;`)[0];
#                 popup_4bbc54f1a99fa3befe416823a46d4ba4.setContent(html_d254b1bc9717fe5074e1a19f6397d5c1);
#
#
#
#         marker_92fe43d7126f3c589c967e9c49a97832.bindPopup(popup_4bbc54f1a99fa3befe416823a46d4ba4)
#         ;
#
#
#
#
#             marker_92fe43d7126f3c589c967e9c49a97832.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Customer 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7ca3bdfd98be07a5d9f9ac987f62f063 = L.marker(
#                 [35.6101355, -108.5282439],
#                 {}
#             ).addTo(map_ba0ed9f858085aa5d0e18246bfe77bf8);
#
#
#             var icon_5a76ea15197d6b8af57dbc5600693a0a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7ca3bdfd98be07a5d9f9ac987f62f063.setIcon(icon_5a76ea15197d6b8af57dbc5600693a0a);
#
#
#         var popup_45cdd321f503a38a83

# %%
### NN Time 1

# Load the data from excel sheet
NNtime1 = pd.read_excel("Subsets_Afreen.xlsx", engine="openpyxl", sheet_name="NN Time 1")

# convert to csv file 
NNtime1.to_csv("NN Time 1.csv",index=False)

# read csv file 
NNtime1_df = pd.read_csv("NN Time 1.csv", header=0)

# clean data 
NNtime1_df.columns = NNtime1_df.columns.str.strip()

# list of tuples that zips together each row household's data with the following columns
coords = list(zip(NNtime1_df['Latitude'], NNtime1_df['Longitude'], 
                  NNtime1_df['Preferred ID'], NNtime1_df['Household size'], 
                  NNtime1_df['Capacity'], NNtime1_df['Delivery Amount'], 
                  NNtime1_df['Inventory'], NNtime1_df['Code for water storage tank']))

# plot on map
NNtime1_m = folium.Map(tiles='OpenStreetMap')

# assign color based on water tank code
def get_color(water_tank_code):
    color_mapping = {
        1200: 'blue',
        275: 'red',
        1000: 'beige',
        1475: 'purple',
        1275: 'orange',
        2200: 'green',
        2475: 'lightgray',
        2000: 'lightgreen',
        3200: 'cadetblue'  
    }
    return color_mapping.get(water_tank_code, 'black')  # black for office and water depots 

# markers colored based on water tank code with popup and hover 
for lat, lon, id, household_size, capacity, delivery_amount, inventory, water_tank_code in coords:
    color = get_color(water_tank_code)
    folium.Marker(
        [lat, lon],
        icon=folium.Icon(color=color),
        tooltip=f"Preferred ID: {id}",  # tooltip for hover
        popup=( 
            f"<b>Household Size:</b> {household_size}<br>"
            f"<b>Capacity:</b> {capacity}<br>"
            f"<b>Delivery Amount:</b> {delivery_amount}<br>"
            f"<b>Inventory:</b> {inventory}"  
        )  # popup for click
    ).add_to(NNtime1_m)

# southwestern US 
sw = [35.3, -108]  
ne = [35.65, -109]  
NNtime1_m.fit_bounds([sw, ne])

# 2 lists of coordinates for line paths between households for 2 different routes 
coordinates = [
    [(35.407167, -108.234917),
    (35.32923797, -108.8098128),
    (35.46312211, -108.9559325),
    (35.6101355, -108.5282439),
    (35.47805444, -108.3411384),
    (35.407167, -108.234917)],
    
    [(35.407167, -108.234917),
    (35.29681843, -108.0062987),
    (35.36235925, -107.968078),
    (35.36601699, -108.0755568),
    (35.407167, -108.234917)]
]

# 2 different colros for both routes 
colors = ['purple', 'green']

# loop to add segment labels 
for points, color in zip(coordinates, colors):
    folium.PolyLine(points, color=color, weight=3, opacity=0.7).add_to(NNtime1_m)

    for i in range(len(points) - 1):
        lat1, lon1 = points[i]
        lat2, lon2 = points[i + 1]

        # Compute midpoint
        mid_lat = (lat1 + lat2) / 2
        mid_lon = (lon1 + lon2) / 2

        # Add segment number above the line
        folium.Marker(
            location=[mid_lat, mid_lon],
            icon=folium.DivIcon(html=f'''
                <div style="
                    font-size: 12pt; 
                    font-weight: bold; 
                    color: black; 
                    background-color: white;
                    padding: 2px; 
                    border-radius: 5px;
                    text-align: center;
                ">
                    {i + 1}
                </div>
            '''),
            tooltip=f"Segment {i + 1}"
        ).add_to(NNtime1_m)

# add title to map
title_html = """
<h3 align="center" style="font-size:24px; margin-top:10px;">
    Routes - NN Time 1
</h3>
"""
NNtime1_m.get_root().html.add_child(Element(title_html))

# save to HTML file
NNtime1_m.save("NN Time1.html")
NNtime1_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e0af30404a67a8be1ae0c7ca1658785 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;h3 align=&quot;center&quot; style=&quot;font-size:24px; margin-top:10px;&quot;&gt;
#     Routes - NN Time 1
# &lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e0af30404a67a8be1ae0c7ca1658785&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e0af30404a67a8be1ae0c7ca1658785 = L.map(
#                 &quot;map_3e0af30404a67a8be1ae0c7ca1658785&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c42783c7388c46a59bc5fd703da3e143 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3e0af30404a67a8be1ae0c7ca1658785);
#
#
#             var marker_25c3db083edcdee40c158e95765caa1e = L.marker(
#                 [35.407167, -108.234917],
#                 {}
#             ).addTo(map_3e0af30404a67a8be1ae0c7ca1658785);
#
#
#             var icon_d2dc2715932459e79f1f0e43cd998fc4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_25c3db083edcdee40c158e95765caa1e.setIcon(icon_d2dc2715932459e79f1f0e43cd998fc4);
#
#
#         var popup_eef20cf93050f7954f49e10c3d523987 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_85d8c32845e2490bdb84e2384a67a05f = $(`&lt;div id=&quot;html_85d8c32845e2490bdb84e2384a67a05f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; nan&lt;/div&gt;`)[0];
#                 popup_eef20cf93050f7954f49e10c3d523987.setContent(html_85d8c32845e2490bdb84e2384a67a05f);
#
#
#
#         marker_25c3db083edcdee40c158e95765caa1e.bindPopup(popup_eef20cf93050f7954f49e10c3d523987)
#         ;
#
#
#
#
#             marker_25c3db083edcdee40c158e95765caa1e.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Depot
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_404196dda9730f441c1afdd369e2e229 = L.marker(
#                 [35.32923797, -108.8098128],
#                 {}
#             ).addTo(map_3e0af30404a67a8be1ae0c7ca1658785);
#
#
#             var icon_618de14f2503e3aa7b00c4e546ad6fad = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_404196dda9730f441c1afdd369e2e229.setIcon(icon_618de14f2503e3aa7b00c4e546ad6fad);
#
#
#         var popup_c9566235fac8e4a25adfc2108c2a02fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ee816358392a9984bc2fbb56d4921c12 = $(`&lt;div id=&quot;html_ee816358392a9984bc2fbb56d4921c12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; 5.0&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; 1200.0&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; 1200.0&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; 1150.0&lt;/div&gt;`)[0];
#                 popup_c9566235fac8e4a25adfc2108c2a02fc.setContent(html_ee816358392a9984bc2fbb56d4921c12);
#
#
#
#         marker_404196dda9730f441c1afdd369e2e229.bindPopup(popup_c9566235fac8e4a25adfc2108c2a02fc)
#         ;
#
#
#
#
#             marker_404196dda9730f441c1afdd369e2e229.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Customer 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b2f9d39b502f45487a711319b35f932e = L.marker(
#                 [35.6101355, -108.5282439],
#                 {}
#             ).addTo(map_3e0af30404a67a8be1ae0c7ca1658785);
#
#
#             var icon_e123e5650a0ddd2338382ff6e1e6d51f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b2f9d39b502f45487a711319b35f932e.setIcon(icon_e123e5650a0ddd2338382ff6e1e6d51f);
#
#
#         var popup_31efd6482c8ccb

# %%
### NN Time 4

# Load the data from excel sheet
NNtime4 = pd.read_excel("Subsets_Afreen.xlsx", engine="openpyxl", sheet_name="NN Time 4")

# convert to csv file 
NNtime4.to_csv("NN Time 4.csv",index=False)

# read csv file 
NNtime4_df = pd.read_csv("NN Time 4.csv", header=0)

# clean data
NNtime4_df.columns = NNtime1_df.columns.str.strip()

# list of tuples that zips together each row household's data with the following columns
coords = list(zip(NNtime4_df['Latitude'], NNtime4_df['Longitude'], 
                  NNtime4_df['Preferred ID'], NNtime4_df['Household size'], 
                  NNtime4_df['Capacity'], NNtime4_df['Delivery Amount'], 
                  NNtime4_df['Inventory'], NNtime4_df['Code for water storage tank']))

# plot on map
NNtime4_m = folium.Map(tiles='OpenStreetMap')

# assign color based on water tank code
def get_color(water_tank_code):
    color_mapping = {
        1200: 'blue',
        275: 'red',
        1000: 'beige',
        1475: 'purple',
        1275: 'orange',
        2200: 'green',
        2475: 'lightgray',
        2000: 'lightgreen',
        3200: 'cadetblue'  
    }
    return color_mapping.get(water_tank_code, 'black')  # black for the other 3 left 

# markers colored based on water tank code with popup and hover 
for lat, lon, id, household_size, capacity, delivery_amount, inventory, water_tank_code in coords:
    color = get_color(water_tank_code)
    folium.Marker(
        [lat, lon],
        icon=folium.Icon(color=color),
        tooltip=f"Preferred ID: {id}",  # tooltip for hover
        popup=( 
            f"<b>Household Size:</b> {household_size}<br>"
            f"<b>Capacity:</b> {capacity}<br>"
            f"<b>Delivery Amount:</b> {delivery_amount}<br>"
            f"<b>Inventory:</b> {inventory}"  
        )  # popup for click
    ).add_to(NNtime4_m)

# southwestern US 
sw = [35.3, -108]  
ne = [35.65, -109]  
NNtime4_m.fit_bounds([sw, ne])

# coordinates for line paths between households 
coordinates = [
    [35.407167, -108.234917],
    [35.29681843, -108.0062987],
    [35.36235925, -107.968078],
    [35.36601699, -108.0755568],
    [35.407167, -108.234917]
]

# Add Polyline to the Map
folium.PolyLine(
    locations=coordinates,  
    color="black",         
    weight=3,               
    opacity=0.7            
).add_to(NNtime4_m)

# loop to add segment labels 
for i in range(len(coordinates) - 1):
    lat1, lon1 = coordinates[i]
    lat2, lon2 = coordinates[i + 1]
    
    # Calculate midpoint
    mid_lat = (lat1 + lat2) / 2
    mid_lon = (lon1 + lon2) / 2

    # Add marker with segment number
    folium.Marker(
        location=[mid_lat, mid_lon],
        icon=folium.DivIcon(html=f'''
                <div style="
                    font-size: 12pt; 
                    font-weight: bold; 
                    color: black; 
                    background-color: white;
                    padding: 2px; 
                    border-radius: 5px;
                    text-align: center;
                ">
                    {i + 1}
                </div>
            '''),
            tooltip=f"Segment {i + 1}"
    ).add_to(NNtime4_m)

# add title to map
title_html = """
<h3 align="center" style="font-size:24px; margin-top:10px;">
    Route - NN Time 4
</h3>
"""
NNtime4_m.get_root().html.add_child(Element(title_html))

# save to HTML file
NNtime4_m.save("NN Time4.html")
NNtime4_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_781d3f9ad6106898433b12495a463b54 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;h3 align=&quot;center&quot; style=&quot;font-size:24px; margin-top:10px;&quot;&gt;
#     Route - NN Time 4
# &lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_781d3f9ad6106898433b12495a463b54&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_781d3f9ad6106898433b12495a463b54 = L.map(
#                 &quot;map_781d3f9ad6106898433b12495a463b54&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_04a4f1b34c7bf4bc669da85039a0506e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_781d3f9ad6106898433b12495a463b54);
#
#
#             var marker_6153835e3a83ecf1f903f78778e84ad2 = L.marker(
#                 [35.407167, -108.234917],
#                 {}
#             ).addTo(map_781d3f9ad6106898433b12495a463b54);
#
#
#             var icon_571696d1dbd580f6478c1b7dc4c7fef0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6153835e3a83ecf1f903f78778e84ad2.setIcon(icon_571696d1dbd580f6478c1b7dc4c7fef0);
#
#
#         var popup_2811814386819ad9f5d8f22d7100048f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_56fe864bb26847759d136b9737a16560 = $(`&lt;div id=&quot;html_56fe864bb26847759d136b9737a16560&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; nan&lt;/div&gt;`)[0];
#                 popup_2811814386819ad9f5d8f22d7100048f.setContent(html_56fe864bb26847759d136b9737a16560);
#
#
#
#         marker_6153835e3a83ecf1f903f78778e84ad2.bindPopup(popup_2811814386819ad9f5d8f22d7100048f)
#         ;
#
#
#
#
#             marker_6153835e3a83ecf1f903f78778e84ad2.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Depot
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1c089c1f0c9e41c2114c2973768754da = L.marker(
#                 [35.32923797, -108.8098128],
#                 {}
#             ).addTo(map_781d3f9ad6106898433b12495a463b54);
#
#
#             var icon_9bf5461164ada094d180f0d6f755c022 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1c089c1f0c9e41c2114c2973768754da.setIcon(icon_9bf5461164ada094d180f0d6f755c022);
#
#
#         var popup_a6597bf6303f4b855d2800db3965722e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e86b195b659eb93a58ecdc8d624f5cb = $(`&lt;div id=&quot;html_0e86b195b659eb93a58ecdc8d624f5cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Household Size:&lt;/b&gt; 5.0&lt;br&gt;&lt;b&gt;Capacity:&lt;/b&gt; 1200.0&lt;br&gt;&lt;b&gt;Delivery Amount:&lt;/b&gt; 0.0&lt;br&gt;&lt;b&gt;Inventory:&lt;/b&gt; 1000.0&lt;/div&gt;`)[0];
#                 popup_a6597bf6303f4b855d2800db3965722e.setContent(html_0e86b195b659eb93a58ecdc8d624f5cb);
#
#
#
#         marker_1c089c1f0c9e41c2114c2973768754da.bindPopup(popup_a6597bf6303f4b855d2800db3965722e)
#         ;
#
#
#
#
#             marker_1c089c1f0c9e41c2114c2973768754da.bindTooltip(
#                 `&lt;div&gt;
#                      Preferred ID: Customer 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_97e4e1d97f4133ba55571197a954a87e = L.marker(
#                 [35.6101355, -108.5282439],
#                 {}
#             ).addTo(map_781d3f9ad6106898433b12495a463b54);
#
#
#             var icon_2a1117a9a5cb691e151462e4576dca97 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_97e4e1d97f4133ba55571197a954a87e.setIcon(icon_2a1117a9a5cb691e151462e4576dca97);
#
#
#         var popup_329787e2ae64bd6f35
